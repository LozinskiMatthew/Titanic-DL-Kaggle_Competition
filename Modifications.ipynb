# %% [markdown]
# Underneath, in this notebook, you may find the prepared, e.t. filled with proper math and logic dataset, which performs greatly (>top 3%) even with untuned Deep Learning Model, which for this task is not suitable (obviously it do requires ML model, due to the highly dispersed low number of elements data datasets).

# %%
#Imports
import tensorflow as tf
import numpy as np
from matplotlib import pyplot as plt
import pandas as pd
import seaborn as sns
from google.colab.data_table import DataTable
pd.set_option('display.max_columns', None)
DataTable.max_columns = 30

# %%
# Getting the data from github
# !wget -O test.csv https://raw.githubusercontent.com/LozinskiMatthew/Titanic-DL-Kaggle_Competition/main/test.csv
# !wget -O train.csv https://raw.githubusercontent.com/LozinskiMatthew/Titanic-DL-Kaggle_Competition/main/train.csv
test_data = pd.read_csv('../content/test.csv')
train_data = pd.read_csv('../content/train.csv')
# Out:
# --2024-08-25 16:54:50--  https://raw.githubusercontent.com/LozinskiMatthew/Titanic-DL-Kaggle_Competition/main/test.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.111.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 28210 (28K) [text/plain]
# Saving to: ‘test.csv’
#
# test.csv            100%[===================>]  27.55K  --.-KB/s    in 0.002s
#
# 2024-08-25 16:54:50 (17.6 MB/s) - ‘test.csv’ saved [28210/28210]
#
# --2024-08-25 16:54:50--  https://raw.githubusercontent.com/LozinskiMatthew/Titanic-DL-Kaggle_Competition/main/train.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 60302 (59K) [text/plain]
# Saving to: ‘train.csv’
#
# train.csv           100%[===================>]  58.89K  --.-KB/s    in 0.01s
#
# 2024-08-25 16:54:50 (4.08 MB/s) - ‘train.csv’ saved [60302/60302]

# %%
# Data cleansed
finding_patterns = pd.concat([train_data, test_data], axis=0)
train_data['Age'].fillna(value=finding_patterns['Age'].mean(), inplace=True)
train_data['Fare'].fillna(value=finding_patterns['Fare'].mean(), inplace=True)
test_data['Age'].fillna(value=finding_patterns['Age'].mean(), inplace=True)
test_data['Fare'].fillna(value=finding_patterns['Fare'].mean(), inplace=True)
train_data['Embarked'].fillna(value='X', inplace=True)
train_data['LetterInCabin'] = train_data['Cabin'].str[0]
test_data['LetterInCabin'] = test_data['Cabin'].str[0]
train_data.drop(['Cabin'], axis=1, inplace=True)
test_data.drop(['Cabin'], axis=1, inplace=True)
train_data['Name'].str.extract('([A-Za-z]+)\.', expand=True)
train_data['Name'] = train_data['Name'].str.extract('([A-Za-z]+)\.', expand=True)
train_data.loc[train_data['Age'] < 12, 'Name'] = 'Kid'
train_data['LetterInCabin'].fillna(value='N', inplace=True)
test_data['Name'] = test_data['Name'].str.extract('([A-Za-z]+)\.', expand=True)
test_data.loc[test_data['Age'] < 12, 'Name'] = 'Kid'
test_data['LetterInCabin'].fillna(value='N', inplace=True)

# %%
# Normalization

from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

ready_train_dataset_scaled = scaler.fit_transform(train_data.drop(['Sex', 'Survived', 'Pclass', 'Ticket', 'Embarked', 'LetterInCabin', 'Name'], axis=1))
ready_train_dataset_scaled_df = pd.DataFrame(data=ready_train_dataset_scaled, columns=train_data.drop(['Sex', 'Survived', 'Pclass', 'Ticket', 'Embarked', 'LetterInCabin', 'Name'], axis=1).columns)
train_data = pd.concat([train_data.drop(['PassengerId', 'Age', 'SibSp', 'Parch', 'Fare'], axis=1), ready_train_dataset_scaled_df], axis=1)

ready_test_dataset_scaled = scaler.fit_transform(test_data.drop(['Sex', 'Pclass', 'Ticket', 'Embarked', 'LetterInCabin', 'Name'], axis=1))
ready_test_dataset_scaled_df = pd.DataFrame(data=ready_test_dataset_scaled, columns=test_data.drop(['Sex', 'Pclass', 'Ticket', 'Embarked', 'LetterInCabin', 'Name'], axis=1).columns)
test_data = pd.concat([test_data.drop(['PassengerId', 'Age', 'SibSp', 'Parch', 'Fare'], axis=1), ready_test_dataset_scaled_df], axis=1)

# %%
# Standardization will be better if you were to decide to work with ML models, which will perform better

'''
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

ready_train_dataset_scaled = scaler.fit_transform(train_data.drop(['Sex', 'Survived', 'Pclass', 'Ticket', 'Embarked', 'LetterInCabin', 'Name'], axis=1))
ready_train_dataset_scaled_df = pd.DataFrame(data=ready_train_dataset_scaled, columns=train_data.drop(['Sex', 'Survived', 'Pclass', 'Ticket', 'Embarked', 'LetterInCabin', 'Name'], axis=1).columns)
train_data = pd.concat([train_data.drop(['PassengerId', 'Age', 'SibSp', 'Parch', 'Fare'], axis=1), ready_train_dataset_scaled_df], axis=1)

ready_test_dataset_scaled = scaler.fit_transform(test_data.drop(['Sex', 'Pclass', 'Ticket', 'Embarked', 'LetterInCabin', 'Name'], axis=1))
ready_test_dataset_scaled_df = pd.DataFrame(data=ready_test_dataset_scaled, columns=test_data.drop(['Sex', 'Pclass', 'Ticket', 'Embarked', 'LetterInCabin', 'Name'], axis=1).columns)
test_data = pd.concat([test_data.drop(['PassengerId', 'Age', 'SibSp', 'Parch', 'Fare'], axis=1), ready_test_dataset_scaled_df], axis=1)

'''
# Out:
# "\nfrom sklearn.preprocessing import StandardScaler\n\nscaler = StandardScaler()\n\nready_train_dataset_scaled = scaler.fit_transform(train_data.drop(['Sex', 'Survived', 'Pclass', 'Ticket', 'Embarked', 'LetterInCabin', 'Name'], axis=1))\nready_train_dataset_scaled_df = pd.DataFrame(data=ready_train_dataset_scaled, columns=train_data.drop(['Sex', 'Survived', 'Pclass', 'Ticket', 'Embarked', 'LetterInCabin', 'Name'], axis=1).columns)\ntrain_data = pd.concat([train_data.drop(['PassengerId', 'Age', 'SibSp', 'Parch', 'Fare'], axis=1), ready_train_dataset_scaled_df], axis=1)\n\nready_test_dataset_scaled = scaler.fit_transform(test_data.drop(['Sex', 'Pclass', 'Ticket', 'Embarked', 'LetterInCabin', 'Name'], axis=1))\nready_test_dataset_scaled_df = pd.DataFrame(data=ready_test_dataset_scaled, columns=test_data.drop(['Sex', 'Pclass', 'Ticket', 'Embarked', 'LetterInCabin', 'Name'], axis=1).columns)\ntest_data = pd.concat([test_data.drop(['PassengerId', 'Age', 'SibSp', 'Parch', 'Fare'], axis=1), ready_test_dataset_scaled_df], axis=1)\n\n"

# %%
# OneHotEncoding
from sklearn.preprocessing import OneHotEncoder
ohe = OneHotEncoder(sparse_output=False)

embarked_encoded_train = ohe.fit_transform(train_data[['Embarked']])
embarked_train_df = pd.DataFrame(data=embarked_encoded_train, columns=ohe.categories_)
embarked_encoded_test = ohe.fit_transform(test_data[['Embarked']])
embarked_test_df = pd.DataFrame(data=embarked_encoded_test, columns=ohe.categories_)
pclass_encoded_train = ohe.fit_transform(train_data['Pclass'].values.reshape(len(train_data), 1))
pclass_train_df = pd.DataFrame(data=pclass_encoded_train, columns=['Low', 'Mid', 'High']) #For convinience and better comprehension
pclass_encoded_test = ohe.fit_transform(test_data['Pclass'].values.reshape(len(test_data), 1))
pclass_test_df = pd.DataFrame(data=pclass_encoded_test, columns=['Low', 'Mid', 'High'])
sex_encoded_train = ohe.fit_transform(train_data[['Sex']]) # Wow it is shortening for reshape in this context for y is 1!!
sex_train_df = pd.DataFrame(data=sex_encoded_train, columns=['Female', 'Male'])
sex_encoded_test = ohe.fit_transform(test_data[['Sex']])
sex_test_df = pd.DataFrame(data=sex_encoded_test, columns=['Female', 'Male'])
letter_encoded_train = ohe.fit_transform(train_data[['LetterInCabin']])
letter_train_df = pd.DataFrame(data=letter_encoded_train, columns=['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'N'])
letter_encoded_test = ohe.fit_transform(test_data[['LetterInCabin']])
letter_test_df = pd.DataFrame(data=letter_encoded_test, columns=['A', 'B', 'C', 'D', 'E', 'F', 'G', 'N'])
ticket_encoded_train = ohe.fit_transform(train_data[['Ticket']])
ticket_train_df = pd.DataFrame(data=ticket_encoded_train, columns=ohe.categories_)
ticket_encoded_test = ohe.fit_transform(test_data[['Ticket']])
ticket_test_df = pd.DataFrame(data=ticket_encoded_test, columns=ohe.categories_)
name_encoded_train = ohe.fit_transform(train_data[['Name']])
name_train_df = pd.DataFrame(data=name_encoded_train, columns=ohe.categories_)
name_encoded_test = ohe.fit_transform(test_data[['Name']])
name_test_df = pd.DataFrame(data=name_encoded_test, columns=ohe.categories_)
final_train_data = pd.concat([train_data.drop(['Pclass', 'Sex', 'Ticket', 'Embarked', 'LetterInCabin', 'Name'], axis=1), embarked_train_df, pclass_train_df, sex_train_df, letter_train_df, ticket_train_df, name_train_df], axis=1)
final_test_data = pd.concat([test_data.drop(['Pclass', 'Sex', 'Ticket', 'Embarked', 'LetterInCabin', 'Name'], axis=1), embarked_test_df, pclass_test_df, sex_test_df, letter_test_df, ticket_test_df, name_test_df], axis=1)
final_test_data = final_test_data.reindex(columns=final_train_data.columns, fill_value=0.0)
final_test_data.drop(columns=['Survived'], inplace=True)

# %%
# Float64 convergence, you may need it in some cases, and it does not hurt the algorithm, models do love numbers
final_train_data['SibSp'] =  final_train_data['SibSp'].astype('float64')
final_train_data['Parch'] =  final_train_data['Parch'].astype('float64')
final_train_data['Survived'] =  final_train_data['Survived'].astype('float64')

final_test_data['SibSp'] =  final_test_data['SibSp'].astype('float64')
final_test_data['Parch'] =  final_test_data['Parch'].astype('float64')
final_test_data['PassengerId'] =  final_test_data['PassengerId'].astype('float64')

# %%
# Creating final datasets to work with
final_train_data_labels = final_train_data.drop(columns=['Survived'])
final_train_data_target = final_train_data['Survived']
train_labels_np = final_train_data_labels.to_numpy()
train_target_np = final_train_data_target.to_numpy()
test_np = final_test_data.to_numpy()

# %%
#For training your models, experimenting with your models, you should use validation dataset, e.t. uncomment below, and use it for fit, and add proper callbacks

divisor = np.round(float(len(final_train_data)) * 85 / 100)
divisor = int(divisor)
train_np_labels = final_train_data_labels[:divisor].to_numpy()
train_np_target = final_train_data_target[:divisor].to_numpy()
valid_np_labels = final_train_data_labels[divisor:].to_numpy()
valid_np_target = final_train_data_target[divisor:].to_numpy()

# %%
# Just for you, func with Callbacks, were you to choose validation dataset, remember to uncomment these lines, tip. you can do it simultaneously via holding alt key, and pointing directions then ctrl+/
class CallbackCreator(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs=None):
        print(f"Epoch {epoch+1}:")
        print(f" - Loss: {logs['loss']}")
        print(f" - Accuracy: {logs['accuracy']}")
        # print(f" - Precision: {logs['precision']}")
        # print(f" - Recall: {logs['recall']}")
        print(f" - Validation Loss: {logs['val_loss']}")
        print(f" - Validation mae: {logs['val_accuracy']}")
        # print(f" = Validation Precision: {logs['val_precision']}")
        # print(f" - Recall: {logs['val_recall']}")

# %% [markdown]
# That is the place for your model, were you to choose to go with DL, just write your model below, but in ML case, you should uncomment the standardization, and comment the normalization cell.

# %% [markdown]
# And beneath, lies a way to add to your model, final results, e.t. survived or not, just replace model_0 with  your current model name.

# %%
# Your model_0, random model that scores in top 3% with DL


model_0 = tf.keras.Sequential([
    tf.keras.layers.Dense(100, activation='relu'),
    tf.keras.layers.Dense(60, activation='relu'),
    tf.keras.layers.Dense(40, activation='relu'),
    tf.keras.layers.Dense(20, activation='relu'),
    tf.keras.layers.Dense(10, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_accuracy', patience=10)

loss = tf.keras.losses.BinaryFocalCrossentropy()
optimizer = tf.keras.optimizers.Adam(learning_rate=0.0001)
model_0.compile(loss=loss, optimizer=optimizer, metrics=['accuracy', 'f1_score'])

model_0.fit(x=train_np_labels, y=train_np_target, epochs=80, verbose=1, batch_size=512 callbacks=[CallbackCreator(), early_stopping], validation_data=(valid_np_labels, valid_np_target.reshape(1, -1)))
# 0.79425
# Out:
#   File "<ipython-input-42-95f72818cbec>", line 19
#     model_0.fit(x=train_np_labels, y=train_np_target, epochs=80, verbose=1, batch_size=512 callbacks=[CallbackCreator(), early_stopping], validation_data=(valid_np_labels, valid_np_target.reshape(1, -1)))
#                                                                                        ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
model_1 = tf.keras.Sequential([
    tf.keras.layers.Dense(100, activation='relu'),
    tf.keras.layers.Dense(80, activation='relu'),
    tf.keras.layers.Dense(60, activation='relu'),
    tf.keras.layers.Dense(10, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

loss = tf.keras.losses.BinaryFocalCrossentropy()
optimizer = tf.keras.optimizers.SGD(learning_rate=0.0001)
model_1.compile(loss=loss, optimizer=optimizer, metrics=['accuracy', 'precision'])

model_1.fit(x=train_np_labels, y=train_np_target, epochs=70, batch_size verbose=1, callbacks=CallbackCreator(), validation_data=(valid_np_labels, valid_np_target))
# Out:
# Epoch 1/70
# 14/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5216 - loss: 0.1751 - precision: 0.1316    Epoch 1:
#  - Loss: 0.17216479778289795
#  - Accuracy: 0.5957728028297424
#  - Validation Loss: 0.1676393300294876
#  - Validation mae: 0.6716417670249939
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.5525 - loss: 0.1740 - precision: 0.2142 - val_accuracy: 0.6716 - val_loss: 0.1676 - val_precision: 1.0000
# Epoch 2/70
# 16/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6199 - loss: 0.1689 - precision: 0.8679 Epoch 2:
#  - Loss: 0.1671939641237259
#  - Accuracy: 0.6354029178619385
#  - Validation Loss: 0.16239482164382935
#  - Validation mae: 0.7089552283287048
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6257 - loss: 0.1684 - precision: 0.8945 - val_accuracy: 0.7090 - val_loss: 0.1624 - val_precision: 1.0000
# Epoch 3/70
# 13/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7091 - loss: 0.1619 - precision: 0.9417  Epoch 3:
#  - Loss: 0.16203123331069946
#  - Accuracy: 0.6789960265159607
#  - Validation Loss: 0.15549390017986298
#  - Validation mae: 0.753731369972229
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6983 - loss: 0.1619 - precision: 0.9373 - val_accuracy: 0.7537 - val_loss: 0.1555 - val_precision: 0.9375
# Epoch 4/70
# 15/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7115 - loss: 0.1582 - precision: 0.9245 Epoch 4:
#  - Loss: 0.15562520921230316
#  - Accuracy: 0.7239101529121399
#  - Validation Loss: 0.1477806717157364
#  - Validation mae: 0.8059701323509216
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7193 - loss: 0.1572 - precision: 0.9199 - val_accuracy: 0.8060 - val_loss: 0.1478 - val_precision: 0.9200
# Epoch 5/70
# 12/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.

# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9969 - loss: 0.0056 - precision: 0.9933 - val_accuracy: 0.8284 - val_loss: 0.1191 - val_precision: 0.7400
# Epoch 63/70
# 17/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9902 - loss: 0.0061 - precision: 0.9807Epoch 63:
#  - Loss: 0.0041150725446641445
#  - Accuracy: 0.9960370063781738
#  - Validation Loss: 0.11957357823848724
#  - Validation mae: 0.8208954930305481
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9919 - loss: 0.0055 - precision: 0.9844 - val_accuracy: 0.8209 - val_loss: 0.1196 - val_precision: 0.7347
# Epoch 64/70
# 19/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9958 - loss: 0.0038 - precision: 0.9916Epoch 64:
#  - Loss: 0.004032909870147705
#  - Accuracy: 0.9947159886360168
#  - Validation Loss: 0.11984120309352875
#  - Validation mae: 0.8208954930305481
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9956 - loss: 0.0038 - precision: 0.9913 - val_accuracy: 0.8209 - val_loss: 0.1198 - val_precision: 0.7347
# Epoch 65/70
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9957 - loss: 0.0041 - precision: 0.9930Epoch 65:
#  - Loss: 0.003976527601480484
#  - Accuracy: 0.9960370063781738
#  - Validation Loss: 0.11952703446149826
#  - Validation mae: 0.8208954930305481
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9958 - loss: 0.0041 - precision: 0.9930 - val_accuracy: 0.8209 - val_loss: 0.1195 - val_precision: 0.7347
# Epoch 66/70
# 23/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9979 - loss: 0.0029 - precision: 0.9986Epoch 66:
#  - Loss: 0.004230907652527094
#  - Accuracy: 0.9947159886360168
#  - Validation Loss: 0.12196895480155945
#  - Validation mae: 0.8059701323509216
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9976 - loss: 0.0030 - precision: 0.9979 - val_accuracy: 0.8060 - val_loss: 0.1220 - val_precision: 0.7059
# Epoch 67/70
# 15/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9913 - loss: 0.0083 - precision: 0.9793 Epoch 67:
#  - Loss: 0.004068942274898291
#  - Accuracy: 0.997357964515686
#  - Validation Loss: 0.1208968386054039
#  - Validation mae: 0.8208954930305481
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9935 - loss: 0.0067 - precision: 0.9860 - val_accuracy: 0.8209 - val_loss: 0.1209 - val_precision: 0.7347
# Epoch 68/70
# 14/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9943 - loss: 0.0035 - precision: 0.9898 Epoch 68:
#  - Loss: 0.003679318353533745
#  - Accuracy: 0.9960370063781738
#  - Validation Loss: 0.12460586428642273
#  - Validation mae: 0.8059701323509216
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9953 - loss: 0.0034 - precision: 0.9924 - val_accuracy: 0.8060 - val_loss: 0.1246 - val_precision: 0.6981
# Epoch 69/70
# 21/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9946 - loss: 0.0044 - precision: 0.9860Epoch 69:
#  - Loss: 0.003991876263171434
#  - Accuracy: 0.9947159886360168
#  - Validation Loss: 0.12374643236398697
#  - Validation mae: 0.8134328126907349
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9946 - loss: 0.0043 - precision: 0.9866 - val_accuracy: 0.8134 - val_loss: 0.1237 - val_precision: 0.7200
# Epoch 70/70
# 14/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9997 - loss: 0.0020 - precision: 0.9992      Epoch 70:
#  - Loss: 0.003611528081819415
#  - Accuracy: 0.9947159886360168
#  - Validation Loss: 0.12334117293357849
#  - Validation mae: 0.8208954930305481
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9977 - loss: 0.0026 - precision: 0.9951 - val_accuracy: 0.8209 - val_loss: 0.1233 - val_precision: 0.7347

# %%
test_data_v2 = pd.read_csv('../content/test.csv')
final_result = pd.DataFrame(data=test_data_v2['PassengerId'], columns=['PassengerId'])
test_length = len(final_test_data)
for i in range(test_length):
    input_data = test_np[i].reshape(1, -1)
    prediction = np.round(model_0.predict(input_data, verbose=1))
    final_result.loc[i, 'Survived'] = prediction
    print(prediction)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# [[1.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# [[0.]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# [[1.]]

# %% [markdown]
# At the end you can see how to save it to the file.

# %%
final_result.to_csv('my_submission.csv', index=False)

# %% [markdown]
# Have fun!!!
